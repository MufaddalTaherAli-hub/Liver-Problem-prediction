# %%
# importing dependency library 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')

# %%
df=pd.read_csv('Indian Liver Patient Dataset (ILPD).csv')

# %%
df
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0     65  Female            0.7               0.1           187       16
# 1     62    Male           10.9               5.5           699       64
# 2     62    Male            7.3               4.1           490       60
# 3     58    Male            1.0               0.4           182       14
# 4     72    Male            3.9               2.0           195       27
# ..   ...     ...            ...               ...           ...      ...
# 578   60    Male            0.5               0.1           500       20
# 579   40    Male            0.6               0.1            98       35
# 580   52    Male            0.8               0.2           245       48
# 581   31    Male            1.3               0.5           184       29
# 582   38    Male            1.0               0.3           216       21
#
#      ag_ratio  sgpt  sgot  alkphos  is_patient
# ...

# %%
# checking target value and counts
df['is_patient'].value_counts() ## 1=> patient has liver problem # and 2=> has no liver problem
# Out:
# is_patient
# 1    416
# 2    167
# Name: count, dtype: int64

# %%
# checking for null values
df.isnull().sum()
# Out:
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             4
# is_patient          0
# dtype: int64

# %%
# percentage of missing values
df['alkphos'].isnull().sum() / len(df)
# Out:
# np.float64(0.00686106346483705)

# %%
# dropping missing values bcz its not affecting our dataset
df.dropna(inplace=True)

# %%
# number of rows and columns
print(f'number of rows : {df.shape[0]}')
print(f'number of columns : {df.shape[1]}')
# Out:
# number of rows : 579
# number of columns : 11

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.hist(bins=30, color='lightblue', figsize=(20,18),edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'tot_bilirubin'}>,
#         <Axes: title={'center': 'direct_bilirubin'}>],
#        [<Axes: title={'center': 'tot_proteins'}>,
#         <Axes: title={'center': 'albumin'}>,
#         <Axes: title={'center': 'ag_ratio'}>],
#        [<Axes: title={'center': 'sgpt'}>,
#         <Axes: title={'center': 'sgot'}>,
#         <Axes: title={'center': 'alkphos'}>],
#        [<Axes: title={'center': 'is_patient'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
tot_mean = df.groupby('is_patient')['tot_bilirubin'].mean()
sns.set_style("ticks")
sns.barplot(tot_mean, color='lightblue', edgecolor='black')
plt.title('Average tot_bilirubin of whether patient has liver problem or not')
plt.grid()
plt.show()

# %%
# if patient has average greater than 1 of tot_bilirubin so that has 100% chances of liver problem

# %%
direct_mean = df.groupby('is_patient')['direct_bilirubin'].mean()
sns.set_style("ticks")
sns.barplot(direct_mean, color='lightblue', edgecolor='black')
plt.title('Average direct_bilirubin of whether patient has liver problem or not')
plt.grid()
plt.show()

# %%
# if patient has average greater than close to 0.60 of direct_bilirubin so that has 100% chances of liver problem

# %%
protiens_mean = df.groupby('is_patient')['tot_proteins'].mean()
sns.barplot(protiens_mean, color='lightblue', edgecolor='black')
plt.title('Average tot_proteins of whether patient has liver problem or not')
plt.show()

# %%
albumin_mean = df.groupby('is_patient')['albumin'].mean()
sns.barplot(albumin_mean, color='lightblue', edgecolor='black')
plt.title('Average albumin of whether patient has liver problem or not')
plt.show()

# %%
ag_mean = df.groupby('is_patient')['ag_ratio'].mean()
sns.barplot(ag_mean, color='lightblue', edgecolor='black')
plt.title('Average ag_ratio of whether patient has liver problem or not')
plt.show()

# %%
sgpt_mean = df.groupby('is_patient')['sgpt'].mean()
sns.barplot(sgpt_mean, color='lightblue', edgecolor='black')
plt.title('Average sgpt of whether patient has liver problem or not')
plt.show()

# %%
sgot_mean = df.groupby('is_patient')['sgot'].mean()
sns.barplot(sgot_mean, color='lightblue', edgecolor='black')
plt.title('Average sgot of whether patient has liver problem or not')
plt.show()

# %%
alkphos_mean = df.groupby('is_patient')['alkphos'].mean()
sns.barplot(alkphos_mean, color='lightblue', edgecolor='black')
plt.title('Average alkphos of whether patient has liver problem or not')
plt.show()

# %%
df.boxplot(figsize=(14,8))
plt.xticks(rotation=90)
plt.title('Box plot')
# Out:
# Text(0.5, 1.0, 'Box plot')

# %%
gender_count = df['gender'].value_counts()

plt.pie(gender_count, labels=gender_count.index, autopct='%0.1f%%', startangle=80)
plt.title('Distribution of Gender')
plt.show()

# %%
sns.displot(x='gender', hue='is_patient', data=df, palette='coolwarm')
plt.title('Distribution of Gender having liver problem or not')
plt.legend(labels=['No_liver_problem', 'Having_liver_problem'])
plt.show()

# %% [markdown]
# ## Preprocess

# %%
df.head(2)
# Out:
#    age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0   65  Female            0.7               0.1           187       16
# 1   62    Male           10.9               5.5           699       64
#
#    ag_ratio  sgpt  sgot  alkphos  is_patient
# 0        18   6.8   3.3     0.90           1
# 1       100   7.5   3.2     0.74           1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_gender = LabelEncoder()

df['gender'] = le_gender.fit_transform(df['gender'])

# %%
df.head(2)
# Out:
#    age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0   65       0            0.7               0.1           187       16
# 1   62       1           10.9               5.5           699       64
#
#    ag_ratio  sgpt  sgot  alkphos  is_patient
# 0        18   6.8   3.3     0.90           1
# 1       100   7.5   3.2     0.74           1

# %% [markdown]
# # machine learning

# %%
x = df.drop('is_patient', axis=1)
y= df['is_patient']

# %%
print(x.shape)
print(y.shape)
# Out:
# (579, 10)
# (579,)

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE()
x_res, y_res = sm.fit_resample(x, y)

# %%
y_res.value_counts()
# Out:
# is_patient
# 1    414
# 2    414
# Name: count, dtype: int64

# %%
y.value_counts()
# Out:
# is_patient
# 1    414
# 2    165
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_res, y_res, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (662, 10)
# (166, 10)
# (662,)
# (166,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# __1. Logistic Regression__

# %%
model_log = LogisticRegression()
model_log.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
log_y_pred = model_log.predict(X_test)

# %%
from sklearn import metrics

# %%
log_cm = metrics.confusion_matrix(y_test, log_y_pred)
print(log_cm)
print('-'*100)
sns.heatmap(log_cm, annot=True, fmt='.0f', color = 'b')
plt.show()
# Out:
# [[49 32]
#  [ 9 76]]
# ----------------------------------------------------------------------------------------------------

# %%
print(metrics.classification_report(y_test, log_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.84      0.60      0.71        81
#            2       0.70      0.89      0.79        85
#
#     accuracy                           0.75       166
#    macro avg       0.77      0.75      0.75       166
# weighted avg       0.77      0.75      0.75       166

# %%
log_score = metrics.accuracy_score(y_test, log_y_pred)
log_score
# Out:
# 0.7530120481927711

# %% [markdown]
# __2. Decision Tree__

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_tree = DecisionTreeClassifier()
model_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree_y_pred = model_tree.predict(X_test)

# %%
tree_cm = metrics.confusion_matrix(y_test, tree_y_pred)
print(tree_cm)
print('-'*100)
sns.heatmap(tree_cm, annot=True, fmt='.0f', color = 'b')
plt.show()
# Out:
# [[62 19]
#  [19 66]]
# ----------------------------------------------------------------------------------------------------

# %%
print(metrics.classification_report(y_test, tree_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.77      0.77      0.77        81
#            2       0.78      0.78      0.78        85
#
#     accuracy                           0.77       166
#    macro avg       0.77      0.77      0.77       166
# weighted avg       0.77      0.77      0.77       166

# %%
tree_score = metrics.accuracy_score(y_test, tree_y_pred)
tree_score
# Out:
# 0.7710843373493976

# %% [markdown]
# __3. Random Forest__

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_forest = RandomForestClassifier()
model_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
forest_y_pred = model_forest.predict(X_test)

# %%
forest_cm = metrics.confusion_matrix(y_test, forest_y_pred)
print(forest_cm)
print('-'*100)
sns.heatmap(forest_cm, annot=True, fmt='.0f', color = 'b')
plt.show()
# Out:
# [[59 22]
#  [13 72]]
# ----------------------------------------------------------------------------------------------------

# %%
print(metrics.classification_report(y_test, forest_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      0.73      0.77        81
#            2       0.77      0.85      0.80        85
#
#     accuracy                           0.79       166
#    macro avg       0.79      0.79      0.79       166
# weighted avg       0.79      0.79      0.79       166

# %%
forest_score = metrics.accuracy_score(y_test, forest_y_pred)
forest_score
# Out:
# 0.7891566265060241

# %% [markdown]
# __4. KNeighborsClassifier__

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_neighbor = KNeighborsClassifier()
model_neighbor.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_y_pred = model_neighbor.predict(X_test)

# %%
knn_cm = metrics.confusion_matrix(y_test, knn_y_pred)
print(knn_cm)
print('-'*100)
sns.heatmap(knn_cm, annot=True, fmt='.0f', color = 'b')
plt.show()
# Out:
# [[52 29]
#  [20 65]]
# ----------------------------------------------------------------------------------------------------

# %%
print(metrics.classification_report(y_test, knn_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.72      0.64      0.68        81
#            2       0.69      0.76      0.73        85
#
#     accuracy                           0.70       166
#    macro avg       0.71      0.70      0.70       166
# weighted avg       0.71      0.70      0.70       166

# %%
knn_score = metrics.accuracy_score(y_test, knn_y_pred)
knn_score
# Out:
# 0.7048192771084337

# %% [markdown]
# __Random Forest has a highest accuracy__

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
gb_y_pred = gb.predict(X_test)

# %%
gb_cm = metrics.confusion_matrix(y_test, gb_y_pred)
print(gb_cm)
print('-'*100)
sns.heatmap(gb_cm, annot=True, fmt='.0f', color = 'b')
plt.show()
# Out:
# [[60 21]
#  [14 71]]
# ----------------------------------------------------------------------------------------------------

# %%
print(metrics.classification_report(y_test, gb_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.81      0.74      0.77        81
#            2       0.77      0.84      0.80        85
#
#     accuracy                           0.79       166
#    macro avg       0.79      0.79      0.79       166
# weighted avg       0.79      0.79      0.79       166

# %%
gb_score = metrics.accuracy_score(y_test, gb_y_pred)
gb_score
# Out:
# 0.7891566265060241

# %%
values = gb.feature_importances_

# %%
names = gb.feature_names_in_

# %%
important_features = pd.DataFrame({'Names' : names, 'Values' : values})

# %%
important_features.sort_values(by='Values')[::-1]
# Out:
#               Names    Values
# 3  direct_bilirubin  0.267796
# 5           albumin  0.145555
# 2     tot_bilirubin  0.124393
# 0               age  0.108590
# 4      tot_proteins  0.105649
# 9           alkphos  0.068638
# 6          ag_ratio  0.053771
# 7              sgpt  0.045443
# 8              sgot  0.044052
# 1            gender  0.036112

# %%
models = ['LogisticRegression', 'DecisionTree', 'RandomForest', 'KNearestNeighbors', 'GradientBoosting']
score = [log_score, tree_score, forest_score, knn_score, gb_score]

accuracy_score = pd.DataFrame(data=score, index=models, columns=['Score'])

# %%
accuracy_score
# Out:
#                        Score
# LogisticRegression  0.753012
# DecisionTree        0.771084
# RandomForest        0.789157
# KNearestNeighbors   0.704819
# GradientBoosting    0.789157

# %%
sns.barplot(data=accuracy_score.reset_index(), x='index', y='Score')
plt.title('Models Accuracy Comparison')
plt.xlabel('Model')
plt.ylabel('Accuracy Score')
plt.xticks(rotation=90)
plt.show()

# %%
X_train
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 593   58       0       0.824124          0.224124           145       24
# 781   43       1       0.808513          0.204257           170       49
# 71    75       0       0.800000          0.200000           188       20
# 49    55       1      18.400000          8.800000           206       64
# 267   37       1       0.700000          0.200000           235       96
# ..   ...     ...            ...               ...           ...      ...
# 763   26       0       0.663719          0.150975           135       21
# 192   60       1       2.300000          0.600000           272       79
# 629   48       0       0.765227          0.165227           141       24
# 559   64       1       1.400000          0.500000           298       31
# 684   32       1       1.146584          0.347951           187       24
#
#      ag_ratio      sgpt      sgot   alkphos
# 593        23  6.534536  3.751753  1.327928
# ...

# %% [markdown]
# # new Prediction

# %%
x_data = np.array([[51, 1, 0.742651, 0.157061, 177, 24, 24, 6.671182, 3.856772, 1.342651]])
model_forest.predict(x_data)
# Out:
# array([2])

# %% [markdown]
# # Save the model

# %%
import pickle

# %%
data = {"model": model_forest}
with open('saved_steps.pkl', 'wb') as file:
    pickle.dump(data, file)

# %%
with open('saved_steps.pkl', 'rb') as file:
    data = pickle.load(file)

model_loaded = data["model"]

# %%
y_pred = model_loaded.predict(x_data)
y_pred
# Out:
# array([2])

# %%
X_test
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 628   27       0       0.617140          0.205713           159       15
# 103   55       0       0.800000          0.200000           225       14
# 8     17       1       0.900000          0.300000           202       22
# 258   33       1       1.500000          7.000000           505      205
# 626   22       1       2.525462          0.928131           162       79
# ..   ...     ...            ...               ...           ...      ...
# 251   38       0       0.700000          0.100000           152       90
# 425   73       1       1.900000          0.700000          1750      102
# 749   26       0       0.627953          0.209318           160       26
# 668   52       0       0.666678          0.133339           192       11
# 279   50       1       0.700000          0.200000           188       12
#
#      ag_ratio      sgpt      sgot   alkphos
# 628        16  6.994287  3.551421  1.039994
# ...

# %%
y_test.loc[279]
# Out:
# np.int64(1)

# %%
df
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0     65       0            0.7               0.1           187       16
# 1     62       1           10.9               5.5           699       64
# 2     62       1            7.3               4.1           490       60
# 3     58       1            1.0               0.4           182       14
# 4     72       1            3.9               2.0           195       27
# ..   ...     ...            ...               ...           ...      ...
# 578   60       1            0.5               0.1           500       20
# 579   40       1            0.6               0.1            98       35
# 580   52       1            0.8               0.2           245       48
# 581   31       1            1.3               0.5           184       29
# 582   38       1            1.0               0.3           216       21
#
#      ag_ratio  sgpt  sgot  alkphos  is_patient
# ...
